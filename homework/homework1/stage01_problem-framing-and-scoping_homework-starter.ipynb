# %% [markdown]
# # Homework Starter — Stage 01: Problem Framing & Scoping
# Name: Doris Lee
# Date: 2026-08-18
#
# Use this notebook to draft your scoping paragraph and memo inline. The final
# versions are committed as `README.md` and `docs/stakeholder-memo.md`.

# %%
import os, pathlib, textwrap
REPO_PATH = pathlib.Path.cwd() / "project"  # change this to your repo
for d in ["data/raw", "data/processed", "src", "notebooks", "docs", "reports", "model"]:
    (REPO_PATH / d).mkdir(parents=True, exist_ok=True)
tmpl = textwrap.dedent("""
# Project Title
**Stage:** Problem Framing & Scoping (Stage 01)

## Problem Statement
<Draft your 1–2 paragraphs here>

## Stakeholder & User
<Who decides? Who uses the output? Timing>

## Useful Answer & Decision
<Descriptive/Predictive/Causal; metric/artifact>

## Assumptions & Constraints
<Bullets>

## Known Unknowns / Risks
<Bullets>

## Lifecycle Mapping
- <Goal> → Problem Framing & Scoping (Stage 01) → <Deliverable>

## Repo Plan
data/, src/, notebooks/, docs/
""")
(REPO_PATH / "README.md").write_text(tmpl, encoding="utf-8")
str((REPO_PATH / "README.md").resolve())

# %% [markdown]
# ## Draft: Scoping Paragraph
#
# An individual retail investor reviews a single large-cap stock (AAPL) each
# evening after market close and must decide whether to **hold** the position or
# **trim** it the next trading day. Today that decision is made from gut feel and
# whatever news is at hand, so it is inconsistent, hard to justify, and impossible
# to benchmark.
#
# This project frames a small, reproducible pipeline that ingests daily price
# history, engineers a handful of transparent features, and produces a next-day
# **up / down** forecast. Success is measurable: directional accuracy on a
# held-out test window must beat a naive "always up" baseline, and each forecast
# comes with a plain-language explanation of its top drivers.
#
# Final versions live in `README.md` (full template) and
# `docs/stakeholder-memo.md` (the chosen artifact).

# %% [markdown]
# ## Stakeholder Artifact (choose one)
# ### Option A — Memo (markdown skeleton)
# ```markdown
# # Stakeholder Brief — <Project Title>
# **Audience:** <PM / Risk / Ops> | **Cadence:** <weekly/monthly>
# **Decision Supported:** <rebalance / approve trade / alert>
#
# ## Context
# <Why this matters now>
#
# ## What You'll Receive
# - <forecast / bands / report> on <schedule>
# - Plain-language summary with assumptions
#
# ## Assumptions & Constraints
# - ...
# ```
#
# ### Option B — Framing Slide (1-pager outline)
# - Title, Problem, User, Useful Answer
# - Assumptions/Constraints, Risks, Decision Trigger
#
# ### Option C — Top-of-Notebook Comments
# Add a header cell to your analysis notebook summarizing the above.
